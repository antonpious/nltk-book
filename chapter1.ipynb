# %%
import nltk;

# %%
nltk.download()

# %% [markdown]
# If you get this error
# [nltk_data] CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data] unable to get local issuer certificate (_ssl.c:1000)>
#
#
# Open a terminal and type the following
# open /Applications/Python\ 3.12/Install\ Certificates.command
#
# This should open another window and the installation process should complete
# Then close the jupyter notebook and open again.
#
# You can also do this through the finder windows by going to applications python and clicking on install certificates but sometimes this may not work

# %% [markdown]
# Pick the book option from the pop up. This download pretty much everything
# about 3.5 GB of Data.
# This is very inefficient for people with low bandwidth connection
# In order to get started you had to download so much and wait
# TODO check if selective text can be downloaded on demand
# The default location of the files are under
# /Users/<currentuser>/nltk_data

# %% [markdown]
# Again don't follow the book
# Just import what you are working on and load only those variables you need to use than everything in the book collection

# %%
# doesn't work properly sometimes it loads all text sometimes only text1
from nltk.book import text1
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# look at text 1 contents
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
# Searching through text
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
from nltk.book import text2

print(text2)
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
text2.concordance("affection")
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
from nltk.book import text3
print(text3)
# Out:
# <Text: The Book of Genesis>

# %%
text3.concordance("lived")
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
from nltk.book import text4

print(text4)
# Out:
# <Text: Inaugural Address Corpus>

# %%
# TODO multiple words by the api is taking words together
# no option to send an OR command between words
print("Displaying word 'nation' occurrences")
text4.concordance("nation")
print("Displaying word 'terror' occurrences")
text4.concordance("terror")
print("Displaying word 'god' occurrences")
text4.concordance("god")
# Out:
# Displaying word 'nation' occurrences
# Displaying 25 of 348 matches:
#  to the character of an independent nation seems to have been distinguished by
# f Heaven can never be expected on a nation that disregards the eternal rules o
# first , the representatives of this nation , then consisting of little more th
# , situation , and relations of this nation and country than any which had ever
# , prosperity , and happiness of the nation I have acquired an habitual attachm
# an be no spectacle presented by any nation more pleasing , more noble , majest
# party for its own ends , not of the nation for the national good . If that sol
# tures and the people throughout the nation . On this subject it might become m
# if a personal esteem for the French nation , formed in a residence of seven ye
# f our fellow - citizens by whatever nation , and if success can not be obtaine
# y , continue His blessing upon this nation and its Government and give it all
# ...

# %%
#if you want to look at the occurrences above 25 count
# TODO find out how can this be one call
# Currently you need to use concordance get the count
# Then come back here and get the line list
# NOTE python style guide uses snake case instead of camelCase in 
# many programming languages
# link to google style guide
# https://google.github.io/styleguide/pyguide.html#316-naming
nation_list = text4.concordance_list("nation", lines=348)
print("Total occurrence: ", len(nation_list))
# 0 based so printing the 26th occurrence
occurrence_line_no = 25
occurrence_line_output = nation_list[occurrence_line_no].line
print(f"{occurrence_line_no+1 }th Occurrence:{occurrence_line_output}")
# Out:
# Total occurrence:  348
# 26th Occurrence:stration . The movements of a great nation are connected in all their parts .

# %%
from nltk.book import text5

print(text5)
# Out:
# <Text: Chat Corpus>

# %%
im = "im"
ur = "ur"
lol = "lol"

print(f"Displaying word {im} occurrences")
text5.concordance(im)
print(f"Displaying word {ur} occurrences")
text5.concordance(ur)
print(f"Displaying word {lol} occurrences")
text5.concordance(lol)
# Out:
# Displaying word im occurrences
# Displaying 25 of 149 matches:
#                                   now im left with this gay name :P PART hey e
# what did you but on e-bay i feel like im in the wrong room yeee haw U30 im con
# ike im in the wrong room yeee haw U30 im considering changing my nickname to "
#  the hell outta my freaking PM box .. Im with my fiance !!!!!!!!!!!!!!!! answe
# m impressed . PART hiya room lmao !!! im doin alright thanks omg Finger .. Dee
# th lol JOIN so read it . thanks U7 .. Im happy to have my fiance here !! forwa
# i didnt me phone you . . . sheesh now im that phone perv guy lets hope not U12
# to spain ? i need to go this summer . im a HUGE phone perv ok seriously who wa
# an ... . ACTION video tapes . hey U20 Im blind now . ACTION has left the room
# T u got that right , i dont do shit , im the supervisor Hello U165 . hey U165
#  him in the " untouchable " list U115 im good U6 lmao U7 how r u U128 hehe how
# ...

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
# examine just the contexts that are shared by 
# two or more words
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
# what functions are available on this text object
help(text1)
# Out:
# Help on Text in module nltk.text object:
#
# class Text(builtins.object)
#  |  Text(tokens, name=None)
#  |
#  |  A wrapper around a sequence of simple (string) tokens, which is
#  |  intended to support initial exploration of texts (via the
#  |  interactive console).  Its methods perform a variety of analyses
#  |  on the text's contexts (e.g., counting, concordancing, collocation
#  |  discovery), and display the results.  If you wish to write a
#  |  program which makes use of these analyses, then you should bypass
#  |  the ``Text`` class, and use the appropriate analysis function or
#  |  class directly instead.
#  |
#  |  A ``Text`` is typically initialized from a given document or
#  |  corpus.  E.g.:
#  |
#  |  >>> import nltk.corpus
#  |  >>> from nltk.text import Text
#  |  >>> moby = Text(nltk.corpus.gutenberg.words('melville-moby_dick.txt'))
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, i)
#  |
#  |  __init__(self, tokens, name=None)
# ...

# %%
# as of now there is no way to get the text of the book
# to even go through many other word combination
# not sure what that authors are thinking
# the only way to get the book text is to use the tokens and read vertically the book
# and find the words
text1.tokens
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
# ...

# %%
# make sure you install numpy and the matplotlib libraries
# the location of a word in the text: how many words from the beginning it appears. This 
# positional information can be displayed using a dispersion plot.
#
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
# generating some random text in the various styles
text1.generate()
# Out:
# Building ngram index...
# long , from one to the top - mast , and no coffin and went out a sea
# captain -- this peaking of the whales . , so as to preserve all his
# might had in former years abounding with them , they toil with their
# lances , strange tales of Southern whaling . at once the bravest
# Indians he was , after in vain strove to pierce the profundity . ?
# then ?" a levelled flame of pale , And give no chance , watch him ;
# though the line , it is to be gainsaid . have been
# 'long , from one to the top - mast , and no coffin and went out a sea\ncaptain -- this peaking of the whales . , so as to preserve all his\nmight had in former years abounding with them , they toil with their\nlances , strange tales of Southern whaling . at once the bravest\nIndians he was , after in vain strove to pierce the profundity . ?\nthen ?" a levelled flame of pale , And give no chance , watch him ;\nthough the line , it is to be gainsaid . have been'

# %%
# generate again
# its generating the same text not as the book informed
text1.generate()
# Out:
# long , from one to the top - mast , and no coffin and went out a sea
# captain -- this peaking of the whales . , so as to preserve all his
# might had in former years abounding with them , they toil with their
# lances , strange tales of Southern whaling . at once the bravest
# Indians he was , after in vain strove to pierce the profundity . ?
# then ?" a levelled flame of pale , And give no chance , watch him ;
# though the line , it is to be gainsaid . have been
# 'long , from one to the top - mast , and no coffin and went out a sea\ncaptain -- this peaking of the whales . , so as to preserve all his\nmight had in former years abounding with them , they toil with their\nlances , strange tales of Southern whaling . at once the bravest\nIndians he was , after in vain strove to pierce the profundity . ?\nthen ?" a levelled flame of pale , And give no chance , watch him ;\nthough the line , it is to be gainsaid . have been'

# %%
# Counting Vocabulary
# Total tokens in the text
len(text3)
# Out:
# 44764

# %%
# total unique words and punctuations in the text
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
# frequency of each token to the total text
# from __future__ import division 
# import no longer required as division is part of python
# len(text3) / len(set(text3))
# Out:
# 16.050197203298673

# %%
# frequency of each token to the total text
len(text3) / len(set(text3))
# Out:
# 16.050197203298673

# %%
# count specific word 
# The word is case sensitive
text1.count("Moby")
# Out:
# 84

# %%
# Percentage of its usage
100 * text1.count("Moby") / len(text1)
# Out:
# 0.032206242643365704

# %%
# define function
def lexical_diversity(text): 
    return len(text) / len(set(text))

# %%
# define function
def percentage(count, total): 
    return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 16.050197203298673

# %%
percentage(4, 5)
# Out:
# 80.0

# %%
percentage(text1.count('Moby'), len(text1))
# Out:
# 0.032206242643365704

# %%
# Lists
sent1 = ['Call', 'me', 'Ishmael', '.']
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
from nltk.book import sent2
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
from nltk.book import sent3
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
# Exercise
ex1 = ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']
print(sorted(ex1))
print(len(set(ex1)))
print(ex1.count('the'))
# Out:
# ['Grail', 'Holy', 'Monty', 'Python', 'and', 'the']
# 6
# 1

# %%
#Adding two lists
['Monty', 'Python'] + ['and', 'the', 'Holy', 'Grail']
# Out:
# ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

# %%
# Adding two list variables
sent2 + sent3
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.',
#  'In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
# adding an item to an existing list
sent1.append("Some")
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Some', 'Some']

# %%
# index word in a text list
text4[173]
# Out:
# 'awaken'

# %%
# find the first index of a word
text4.index("awaken")
# Out:
# 173

# %%
# slicing texts from a list
text5[16715:16735]
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
# index are 0 based, the first word is in the 0th index
sent = ['word1', 'word2', 'word3', 'word4', 'word5', 
'word6', 'word7', 'word8', 'word9', 'word10'] 

print(sent[0])
print(sent[9])
# Out:
# word1
# word10

# %%
# runtime error when index is too large
sent[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 # runtime error when index is too large
# ----> 2 sent[10]
#
# IndexError: list index out of range

# %%
# repeating slicing techniques again
print(sent[5:8])
print(sent[5])
print(sent[6])
print(sent[7])
# Out:
# ['word6', 'word7', 'word8']
# word6
# word7
# word8

# %%
# slicing from beginning
sent[:3]
# Out:
# ['word1', 'word2', 'word3']

# %%
# slicing to the end
sent[4:]
# Out:
# ['word5', 'word6', 'word7', 'word8', 'word9', 'word10']

# %%
# changing elements on the list
# though the books says to modify the existing variable
# this is not good if we need to run cells previous
# so copying the existing list before manipulation
sentCopy = sent[0:10]
sentCopy
# Out:
# ['word1',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'word10']

# %%
# manipulate the list
sentCopy[0] = "first"
sentCopy[9] = "last"
sentCopy
# Out:
# ['first',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'last']

# %%
# replace elments 1 to 9 with only two elements
sentCopy[1:9] = ["Second", "Third"]
sentCopy
# Out:
# ['first', 'Second', 'Third', 'last']

# %%
# 10th element is no longer available
sentCopy[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 # 10th element is no longer available
# ----> 2 sentCopy[9]
#
# IndexError: list index out of range

# %%
# The orginal sent is not modified
sent
# Out:
# ['word1',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'word10']

# %%
myList1 = ["one","two", "three", "four"]
myList2 = myList1[1:3]
print(myList2)
myList1[1] = "changedTwo"
print(myList2[0])
print(myList1[1])
# Out:
# ['two', 'three']
# two
# changedTwo

# %%
# Variables
# replace the modified variable
sent1 = ['Call', 'me', 'Ishmael', '.']
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
# copying from existing list
my_sent = ['Bravely', 'bold', 'Sir', 'Robin', ',', 'rode', 
'forth', 'from', 'Camelot', '.']
noun_phrase = my_sent[1:4]
noun_phrase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
# Sorting the list
# Remember that capitalized words appear before lowercase words in sorted lists
words = sorted(noun_phrase)
print(words)
print(noun_phrase)
# Out:
# ['Robin', 'Sir', 'bold']
# ['bold', 'Sir', 'Robin']

# %%
# reserved words in python can't be used as a variable
# def, if, not, and import
not = "throws error"
# Out:
#   Cell In[49], line 3
#     not = "throws error"
#         ^
# SyntaxError: invalid syntax

# %%
# intermediate variables
# note set removes duplicate values in the list and stores only unique values 
total_words_text1 = len(text1)
vocab_text1 = set(text1) 
total_vocab_text1 = len(vocab_text1) 
print(f"total words: {total_words_text1}: Total Vocab:{total_vocab_text1}")
# Out:
# total words: 260819: Total Vocab:19317

# %%
# Strings
name = "Monty"
print(name[0])
print(name[1:3])
print(name[2:])
print(name[:4])
# Out:
# M
# on
# nty
# Mont

# %%
# Multiplication
print(name*2)
# Addition
print(name + "!")
# Out:
# MontyMonty
# Monty!

# %%
# join words with a space like first name last name
" ".join(["John", "Smith", "Junior"])
# Out:
# 'John Smith Junior'

# %%
# split words on a space like a full name to first name and last name
"John Smith Junior".split()
# Out:
# ['John', 'Smith', 'Junior']
